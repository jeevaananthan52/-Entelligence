# %% [markdown]
# <a href="https://colab.research.google.com/github/jeevaananthan52/-Entelligence/blob/main/NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
nltk.download('punkt_tab')

stop_words=set(stopwords.words('english')) # Changed to use parentheses for set creation
text = "This is a sample sentence showing stopword removal."
words=word_tokenize(text.lower())
filter_words=[]
for word in words:
  if word not in stop_words:
    filter_words.append(word)

print(filter_words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['sample', 'sentence', 'showing', 'stopword', 'removal', '.']
